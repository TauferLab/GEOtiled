# %%
import visualize_tests as vt

# %%
csv_file_de = '/media/volume/geotiled-saga/tile_compute_test_de/results.csv'
csv_file_tn = '/media/volume/geotiled-saga/tile_compute_test_tn/results.csv'
csv_file_ca = '/media/volume/geotiled-saga/tile_compute_test_ca/results.csv'

# Create charts for Delaware
vt.visualize_tile_compute(csv_file_de, 'average_compute_time_per_tile', 'Average Execution Time per Tile for Delaware 30m')
vt.visualize_tile_compute(csv_file_de, 'average_compute_mem_usage_per_tile', 'Average Peak Memory Usage per Tile for Delaware 30m')

# Create charts for Tennessee
vt.visualize_tile_compute(csv_file_tn, 'average_compute_time_per_tile', 'Average Execution Time per Tile for Tennessee 30m')
vt.visualize_tile_compute(csv_file_tn, 'average_compute_mem_usage_per_tile', 'Average Peak Memory Usage per Tile for Tennessee 30m')

# Create charts for California
vt.visualize_tile_compute(csv_file_ca, 'average_compute_time_per_tile', 'Average Execution Time per Tile for California 30m')
vt.visualize_tile_compute(csv_file_ca, 'average_compute_mem_usage_per_tile', 'Average Peak Memory Usage per Tile for California 30m')

# %% [markdown]
# # FIN
