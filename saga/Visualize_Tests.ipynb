# %%
import visualize_tests as vt

# %%
csv_file_de = '/media/volume/geotiled-saga/tile_compute_test_de/new_results.csv'
csv_file_tn = '/media/volume/geotiled-saga/tile_compute_test_tn/new_results.csv'
csv_file_ca = '/media/volume/geotiled-saga/tile_compute_test_ca/new_results.csv'

# Create charts for Delaware
# vt.visualize_tile_compute(csv_file_de, 'avg_comp_time_per_tile', 'Average Execution Time per Tile for Delaware 30m')
# vt.visualize_tile_compute(csv_file_de, 'avg_mem_usage_per_tile', 'Average Peak Memory Usage per Tile for Delaware 30m')

# # Create charts for Tennessee
# vt.visualize_tile_compute(csv_file_tn, 'avg_comp_time_per_tile', 'Average Execution Time per Tile for Tennessee 30m')
# vt.visualize_tile_compute(csv_file_tn, 'avg_mem_usage_per_tile', 'Average Peak Memory Usage per Tile for Tennessee 30m')

# Create charts for California
vt.visualize_tile_compute(csv_file_ca, 'avg_comp_time_per_tile', 'Average Execution Time per Tile for California 30m')
vt.visualize_tile_compute(csv_file_ca, 'avg_mem_usage_per_tile', 'Average Peak Memory Usage per Tile for California 30m')

# %%
csv_crop = '/media/volume/geotiled-saga/crop_test/crop_results.csv'
vt.visualize_timing_test(csv_crop, 'Execution Time of Tile Split for California 30m')

# %%
csv_mosaic = '/media/volume/geotiled-saga/tile_compute_test_ca/mosaic_test.csv'
vt.visualize_timing_test(csv_mosaic, 'Execution Time of Mosaicking for Convergence Index of California 30m')
vt.visualize_memory_test(csv_mosaic, 'Peak Memory Usage of Mosaicking for Convergence Index of California 30m')

# %% [markdown]
# # FIN
