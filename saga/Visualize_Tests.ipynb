# %%
import visualize_tests as vt

# %%
csv_file = '/media/volume/geotiled-saga/tile_compute_test_de/results.csv'
compute_param = 'average_compute_time_per_tile'
mem_param = 'average_compute_mem_usage_per_tile'

vt.visualize_tile_compute(csv_file, compute_param, 'Average Execution Time per Tile for Delaware 30m')
vt.visualize_tile_compute(csv_file, mem_param, 'Average Peak Memory Usage per Tile for Delaware 30m')

# %% [markdown]
# # FIN
